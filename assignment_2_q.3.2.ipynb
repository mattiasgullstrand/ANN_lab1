# %%
from RBF_Net import RBF_Net
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
X_train = np.arange(0, 2*math.pi, 0.1)
X_train = X_train.reshape(1, X_train.shape[0])

X_test = np.arange(0.05, 2*math.pi, 0.1)
X_test = X_test.reshape(1, X_test.shape[0])

# %%
def sin_2(x):
    return np.sin(2*x)

# %%
f_train = sin_2(X_train)
f_test = sin_2(X_test)

# %%
dim_list = list(range(1, 50))
errors = []
for H_dim in dim_list:
    rbf_net = RBF_Net(X_train, f_train.T, H_dim, weight_learn = 'delta')
    rbf_net.epochs = 100
    rbf_net.train()
    f_approx = rbf_net.predict(X_test).flatten()
    test_error = np.mean(np.abs(f_approx - f_test))
    errors.append(test_error)
    print("Number of nodes: {}, Error: {}".format(H_dim, test_error))
plt.plot(dim_list, errors)
# Out:
# Number of nodes: 1, Error: 0.5698138586570629
# Number of nodes: 2, Error: 0.5052130217956073
# Number of nodes: 3, Error: 0.5054609966540942
# Number of nodes: 4, Error: 0.3813256256562687
# Number of nodes: 5, Error: 0.438993477584698
# Number of nodes: 6, Error: 0.26786229156252395
# Number of nodes: 7, Error: 0.2893219526384915
# Number of nodes: 8, Error: 0.24594829828433593
# Number of nodes: 9, Error: 0.27223997480896955
# Number of nodes: 10, Error: 0.2658470842195307
# Number of nodes: 11, Error: 0.22379876102064572
# Number of nodes: 12, Error: 0.21998746977946862
# Number of nodes: 13, Error: 0.2329113155425761
# Number of nodes: 14, Error: 0.2153670510866739
# Number of nodes: 15, Error: 0.22090129043075057
# Number of nodes: 16, Error: 0.20055070433126196
# Number of nodes: 17, Error: 0.2095975929823936
# Number of nodes: 18, Error: 0.18975578084554373
# Number of nodes: 19, Error: 0.18929125480438083
# Number of nodes: 20, Error: 0.17240919442108918
# Number of nodes: 21, Error: 0.17124367100265822
# Number of nodes: 22, Error: 0.17939576228119322
# Number of nodes: 23, Error: 0.17129150810071853
# Number of nodes: 24, Error: 0.16124412885791747
# Number of nodes: 25, Error: 0.16555637719332236
# Number of nodes: 26, Error: 0.15639358844484325
# Number of nodes: 27, Error: 0.16329997395143137
# Number of nodes: 28, Error: 0.1411899542787533
# Number of nodes: 29, Error: 0.1545049597349769
# Number of nodes: 30, Error: 0.16628349240074186
# Number of nodes: 31, Error: 0.16182680727793633
# Number of nodes: 32, Error: 0.16072172598808157
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-e30d599af301> in <module>
#       4     rbf_net = RBF_Net(X_train, f_train.T, H_dim, weight_learn = 'delta')
#       5     rbf_net.epochs = 100
# ----> 6     rbf_net.train()
#       7     f_approx = rbf_net.predict(X_test).flatten()
#       8     test_error = np.mean(np.abs(f_approx - f_test))
#
# ~/ANN/RBF_Net.py in train(self)
#      86     def train(self):
#      87         for e in range(self.epochs):
# ---> 88             self.batch_learn_weights()
#      89
#      90     def predict(self, X):
#
# ~/ANN/RBF_Net.py in batch_learn_weights(self)
#      71     def batch_learn_weights(self):
#      72         if self.weight_learn == 'delta':
# ---> 73             self.learn_weights_delta_rule()
#      74         else:
#      75             self.learn_weights_least_squares()
#
# ~/ANN/RBF_Net.py in learn_weights_delta_rule(self)
#      60     def learn_weights_delta_rule(self):
#      61         # Incrementally update the weights with the delta rule
# ---> 62         Phi = self.calc_Phi(self.X)
#      63         f = self.T
#      64         for k in range(self.N):
#
# ~/ANN/RBF_Net.py in calc_Phi(self, X)
#      46                 mu_j = self.mus[j]
#      47                 sigma_j = self.sigmas[j]
# ---> 48                 Phi[i,j] = act_funs.gaussian_rbf(x, mu_j, sigma_j)
#      49         return Phi
#      50
#
# ~/ANN/activation_functions_v2.py in gaussian_rbf(x, mu, sigma)
#       8
#       9 def gaussian_rbf(x, mu, sigma):
# ---> 10     return np.exp(-np.square(x - mu)/(2*np.square(sigma)))
#
# KeyboardInterrupt:

# %%
X_test.shape
# Out:
# (1, 63)

# %%
rbf_net = RBF_Net(X_train, f_train.T, 10, weight_learn = 'delta')
rbf_net.epochs = 700
rbf_net.eta = 0.01
rbf_net.train()
f_approx = rbf_net.predict(X_test).flatten()
plt.plot(X_test[0], f_test[0])
plt.plot(X_test[0], f_approx)

# %%
rbf_net.plot_errors()
# Out:
# Obtained error [0.05250811047362698]

# %%
from RBF_Net import RBF_Net
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
X_train = np.arange(0, 2*math.pi, 0.1)
X_train = X_train.reshape(1, X_train.shape[0])

X_test = np.arange(0.05, 2*math.pi, 0.1)
X_test = X_test.reshape(1, X_test.shape[0])

# %%
def sin_2(x):
    return np.sin(2*x)

# %%
f_train = sin_2(X_train)
f_test = sin_2(X_test)

# %%
dim_list = list(range(1, 50))
errors = []
for H_dim in dim_list:
    rbf_net = RBF_Net(X_train, f_train.T, H_dim, weight_learn = 'delta', CL = False)
    rbf_net.epochs = 100
    rbf_net.train()
    f_approx = rbf_net.predict(X_test).flatten()
    test_error = np.mean(np.abs(f_approx - f_test))
    errors.append(test_error)
    print("Number of nodes: {}, Error: {}".format(H_dim, test_error))
plt.plot(dim_list, errors)
# Out:
# Number of nodes: 1, Error: 0.5698140354610127
# Number of nodes: 2, Error: 0.5052119124274629
# Number of nodes: 3, Error: 0.5054602097001775
# Number of nodes: 4, Error: 0.3814994100451025
# Number of nodes: 5, Error: 0.43929158175964067
# Number of nodes: 6, Error: 0.26388969273331936
# Number of nodes: 7, Error: 0.3165959522827398
# Number of nodes: 8, Error: 0.2534967945303242
# Number of nodes: 9, Error: 0.2481966883508093
# Number of nodes: 10, Error: 0.2575821877451791
# Number of nodes: 11, Error: 0.2501813080030012
# Number of nodes: 12, Error: 0.22158125847527682
# Number of nodes: 13, Error: 0.21610285395452686
# Number of nodes: 14, Error: 0.22115182921177395
# Number of nodes: 15, Error: 0.23662213930626846
# Number of nodes: 16, Error: 0.21533387798517672
# Number of nodes: 17, Error: 0.20487467054903424
# Number of nodes: 18, Error: 0.2108665812640492
# Number of nodes: 19, Error: 0.20489394958841273
# Number of nodes: 20, Error: 0.21481770310186984
# Number of nodes: 21, Error: 0.19802140360943235
# Number of nodes: 22, Error: 0.18719179587654677
# Number of nodes: 23, Error: 0.18187513559014878
# Number of nodes: 24, Error: 0.14629312520162344
# Number of nodes: 25, Error: 0.1722901701837763
# Number of nodes: 26, Error: 0.17023861332350085
# Number of nodes: 27, Error: 0.16627051364274034
# Number of nodes: 28, Error: 0.14676176574013816
# Number of nodes: 29, Error: 0.16105279924446855
# Number of nodes: 30, Error: 0.18175035143468457
# Number of nodes: 31, Error: 0.1523833031050344
# Number of nodes: 32, Error: 0.1606280547080697
# Number of nodes: 33, Error: 0.12821608186126882
# Number of nodes: 34, Error: 0.1038598066296375
# Number of nodes: 35, Error: 0.15258738951333461
# Number of nodes: 36, Error: 0.11752298940166069
# Number of nodes: 37, Error: 0.15235972674761852
# Number of nodes: 38, Error: 0.12756419156430923
# Number of nodes: 39, Error: 0.09941028488161573
# Number of nodes: 40, Error: 0.15308544334507032
# Number of nodes: 41, Error: 0.12428840250704504
# Number of nodes: 42, Error: 0.1144927465957849
# Number of nodes: 43, Error: 0.10950833680447178
# Number of nodes: 44, Error: 0.09916001745622864
# Number of nodes: 45, Error: 0.11121886852118282
# Number of nodes: 46, Error: 0.12882823055979978
# Number of nodes: 47, Error: 0.12074239025637556
# Number of nodes: 48, Error: 0.12492207703216256
# Number of nodes: 49, Error: 0.12022531860483184

# %%
rbf_net = RBF_Net(X_train, f_train.T, 10, weight_learn = 'delta', CL = False)
rbf_net.epochs = 700
rbf_net.eta = 0.01
rbf_net.train()
f_approx = rbf_net.predict(X_test).flatten()
plt.plot(X_test[0], f_test[0])
plt.plot(X_test[0], f_approx)
plt.plot(rbf_net.mus, sin_2(rbf_net.mus), 'bo', color = 'r')

# %%
rbf_net.plot_errors()
# Out:
# Obtained error [0.048999991691879526]

# %%
from RBF_Net import RBF_Net
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
X_train = np.arange(0, 2*math.pi, 0.1)
X_train = X_train.reshape(1, X_train.shape[0])

X_test = np.arange(0.05, 2*math.pi, 0.1)
X_test = X_test.reshape(1, X_test.shape[0])

# %%
def sin_2(x):
    return np.sin(2*x)

# %%
f_train = sin_2(X_train)
f_test = sin_2(X_test)

# %%
dim_list = [2, 3, 5, 10, 20]
errors = []
for H_dim in dim_list:
    rbf_net = RBF_Net(X_train, f_train.T, H_dim, weight_learn = 'delta')
    rbf_net.epochs = 100
    rbf_net.train()
    f_approx = rbf_net.predict(X_test).flatten()
    test_error = np.mean(np.abs(f_approx - f_test))
    errors.append(test_error)
    print("Number of nodes: {}, Error: {}".format(H_dim, test_error))
plt.plot(dim_list, errors)
# Out:
# Number of nodes: 2, Error: 0.6335292941648416
# Number of nodes: 3, Error: 0.5872043820110681
# Number of nodes: 5, Error: 0.37215785605236
# Number of nodes: 10, Error: 0.2507309530344928
# Number of nodes: 20, Error: 0.20629929422640855

# %%
rbf_net.mus
# Out:
# array([0.07599464, 0.39932758, 0.71850788, 1.0118485 , 1.30348026,
#        1.54550335, 1.92980264, 2.21965443, 2.58771432, 2.88756655,
#        3.25932108, 3.59232802, 3.94855146, 4.18160895, 4.48886733,
#        4.83418159, 5.22275903, 5.48568071, 5.83340099, 6.12223114])

# %%
X_test.shape
# Out:
# (1, 63)

# %%
rbf_net = RBF_Net(X_train, f_train.T, 6, weight_learn = 'delta', CL = True)
#plt.plot(rbf_net.mus, sin_2(rbf_net.mus), 'bo', color = 'b')
rbf_net.epochs = 500
rbf_net.eta = 0.01
rbf_net.winners = 1
rbf_net.train()
f_approx = rbf_net.predict(X_test).flatten()
plt.plot(X_test[0], f_test[0])
plt.plot(X_test[0], f_approx)
plt.plot(rbf_net.mus, sin_2(rbf_net.mus), 'bo', color = 'r')

# %%
rbf_net.plot_errors()
# Out:
# Obtained error [0.3621522388071671]

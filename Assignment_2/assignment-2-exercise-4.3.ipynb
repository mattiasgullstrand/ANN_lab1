# %%
import numpy as np
import matplotlib.pyplot as plt
from RBF_Net_4_3 import RBF_Net

# %%
datVotes = [i.strip().split() for i in open("data_lab2/votes.dat").readlines()]
datParty = [i.strip().split() for i in open("data_lab2/mpparty.dat").readlines()]

# %%
votes = datVotes[0]
parties = datParty[0]

# %%
parties = [i.strip().split() for i in open("data_lab2/mpparty.dat").readlines()][3:]

# %%
parties = [i[0] for i in parties]

# %%
votes = votes[0].split(',')

# %%
votes_matrix = np.array(votes, dtype = float).reshape(349, 31).T

# %%
rbf_net = RBF_Net(votes_matrix, 100, parties)

# %%
rbf_net.epochs = 1
rbf_net.train()

# %%
rbf_net.mus
# Out:
# array([[array([[0.8275207 , 0.5975995 , 0.35922915, 0.95846075, 0.32125665,
#         0.36371534, 0.84581553, 0.56023201, 0.38916565, 0.69337605,
#         0.54291525, 0.34707041, 0.26256062, 0.86912919, 0.60709006,
#         0.487562  , 0.37456336, 0.12183851, 0.5978083 , 0.82838354,
#         0.15940545, 0.12228508, 0.60088406, 0.47407782, 0.16022163,
#         0.52895225, 0.40296419, 0.84019914, 0.84291348, 0.09198819,
#         0.74484595]]),
#         array([[1.        , 1.        , 1.        , 0.93284957, 0.99867116,
#         0.99758313, 0.46763315, 0.93284957, 0.99867116, 0.99867116,
#         1.        , 1.        , 0.99999836, 0.50034884, 1.        ,
#         1.        , 0.8397984 , 1.        , 0.9999624 , 0.92907031,
#         0.96705304, 0.46708913, 0.9999626 , 0.99779607, 0.99999831,
#         0.50324259, 0.99999831, 0.99999831, 0.9999983 , 0.99999831,
#         0.5       ]]),
#         array([[0.30190215, 0.46332121, 0.32300286, 0.69575039, 0.39541389,
# ...
